# %% [markdown]
# # Assignment 3

# %% [markdown]
# ## Pandas and plotting exercises

# %%
# Import the pandas library

import pandas as pd

# %% [markdown]
# In Week 2, you used a dataset from the CORGIS website.  You may have used either the Python, CSV, or JSON data files.
#
# For this assignment, use the CSV file format for the same category of data that you used previously.

# %%
# Use pandas read_csv function to import the data into a dataframe variable

food_df = pd.read_csv('food.csv')
food_df
# Out:
#                                       Category  \
# 0                                         Milk
# 1                                         Milk
# 2                                         Milk
# 3                                         Milk
# 4                                         Milk
# ...                                        ...
# 7078          Tomatoes as ingredient in omelet
# 7079  Other vegetables as ingredient in omelet
# 7080         Vegetables as ingredient in curry
# 7081         Sauce as ingredient in hamburgers
# 7082      Industrial oil as ingredient in food
#
#                                    Description  Nutrient Data Bank Number  \
# 0                                  Milk, human                   11000000
# 1                                    Milk, NFS                   11100000
# 2                                  Milk, whole                   11111000
# 3                      Milk, low sodium, whole                   11111100
# 4               Milk, calcium fortified, whole                   11111150
# ...                                        ...                        ...
# 7078          Tomatoes as ingredient in omelet                   99997802
# 7079  Other vegetables as ingredient in omelet                   99997804
# 7080         Vegetables as ingredient in curry                   99997810
# 7081         Sauce as ingredient in hamburgers                   99998130
# 7082      Industrial oil as ingredient in food                   99998210
#
#       Data.Alpha Carotene  Data.Beta Carotene  Data.Beta Cryptoxanthin  \
# 0                       0                   7                        0
# 1                       0                   4                        0
# 2                       0                   7                        0
# 3                       0                   7                        0
# 4                       0                   7                        0
# ...                   ...                 ...                      ...
# 7078                  103                 464                        0
# 7079                    1                  11                        0
# 7080                  368                 994                        0
# 7081                    0                 194                        4
# 7082                    0                   0                        0
#
#       Data.Carbohydrate  Data.Cholesterol  Data.Choline  Data.Fiber  ...  \
# 0                  6.89                14          16.0         0.0  ...
# 1                  4.87                 8          17.9         0.0  ...
# 2                  4.67                12          17.8         0.0  ...
# 3                  4.46                14          16.0         0.0  ...
# 4                  4.67                12          17.8         0.0  ...
# ...                 ...               ...           ...         ...  ...
# 7078               5.48                 0           7.4         1.6  ...
# 7079               4.81                 0          19.4         1.4  ...
# 7080              11.60                 0          14.6         2.2  ...
# 7081              17.14                13          20.0         0.6  ...
# 7082               0.00                 0           0.2         0.0  ...
#
#       Data.Major Minerals.Phosphorus  Data.Major Minerals.Potassium  \
# 0                                 14                             51
# 1                                103                            157
# 2                                101                            150
# 3                                 86                            253
# 4                                101                            150
# ...                              ...                            ...
# 7078                              30                            278
# 7079                              96                            364
# 7080                              46                            312
# 7081                              33                            190
# 7082                               0                              0
#
#       Data.Major Minerals.Sodium  Data.Major Minerals.Zinc  \
# 0                             17                      0.17
# 1                             39                      0.42
# 2                             38                      0.41
# 3                              3                      0.38
# 4                             38                      0.41
# ...                          ...                       ...
# 7078                           6                      0.21
# 7079                           6                      0.58
# 7080                          19                      0.28
# 7081                         845                      0.21
# 7082                           0                      0.01
#
#       Data.Vitamins.Vitamin A - RAE  Data.Vitamins.Vitamin B12  \
# 0                                61                       0.05
# 1                                59                       0.56
# 2                                32                       0.54
# 3                                29                       0.36
# 4                                32                       0.54
# ...                             ...                        ...
# 7078                             43                       0.00
# 7079                              1                       0.04
# 7080                             98                       0.00
# 7081                             21                       0.04
# 7082                              0                       0.00
#
#       Data.Vitamins.Vitamin B6  Data.Vitamins.Vitamin C  \
# 0                        0.011                      5.0
# 1                        0.060                      0.1
# 2                        0.061                      0.0
# 3                        0.034                      0.9
# 4                        0.061                      0.0
# ...                        ...                      ...
# 7078                     0.104                     18.2
# 7079                     0.123                      6.3
# 7080                     0.177                     16.2
# 7081                     0.104                      2.5
# 7082                     0.000                      0.0
#
#       Data.Vitamins.Vitamin E  Data.Vitamins.Vitamin K
# 0                        0.08                      0.3
# 1                        0.03                      0.2
# 2                        0.05                      0.3
# 3                        0.08                      0.3
# 4                        0.05                      0.3
# ...                       ...                      ...
# 7078                     0.60                      8.8
# 7079                     0.03                      0.4
# 7080                     0.24                      8.9
# 7081                     1.90                     50.8
# 7082                    10.50                    155.8
#
# [7083 rows x 38 columns]

# %%
# How many rows and columns does the dataframe have?

food_df.shape
# 7083 columns, 38 rows
# Out:
# (7083, 38)

# %%
# What are the column names of the dataframe?

food_df.columns
# Out:
# Index(['Category', 'Description', 'Nutrient Data Bank Number',
#        'Data.Alpha Carotene', 'Data.Beta Carotene', 'Data.Beta Cryptoxanthin',
#        'Data.Carbohydrate', 'Data.Cholesterol', 'Data.Choline', 'Data.Fiber',
#        'Data.Lutein and Zeaxanthin', 'Data.Lycopene', 'Data.Niacin',
#        'Data.Protein', 'Data.Retinol', 'Data.Riboflavin', 'Data.Selenium',
#        'Data.Sugar Total', 'Data.Thiamin', 'Data.Water',
#        'Data.Fat.Monosaturated Fat', 'Data.Fat.Polysaturated Fat',
#        'Data.Fat.Saturated Fat', 'Data.Fat.Total Lipid',
#        'Data.Major Minerals.Calcium', 'Data.Major Minerals.Copper',
#        'Data.Major Minerals.Iron', 'Data.Major Minerals.Magnesium',
#        'Data.Major Minerals.Phosphorus', 'Data.Major Minerals.Potassium',
#        'Data.Major Minerals.Sodium', 'Data.Major Minerals.Zinc',
#        'Data.Vitamins.Vitamin A - RAE', 'Data.Vitamins.Vitamin B12',
#        'Data.Vitamins.Vitamin B6', 'Data.Vitamins.Vitamin C',
#        'Data.Vitamins.Vitamin E', 'Data.Vitamins.Vitamin K'],
#       dtype='object')

# %%
# What are the datatypes of each column?

food_df.dtypes
# Out:
# Category                           object
# Description                        object
# Nutrient Data Bank Number           int64
# Data.Alpha Carotene                 int64
# Data.Beta Carotene                  int64
# Data.Beta Cryptoxanthin             int64
# Data.Carbohydrate                 float64
# Data.Cholesterol                    int64
# Data.Choline                      float64
# Data.Fiber                        float64
# Data.Lutein and Zeaxanthin          int64
# Data.Lycopene                       int64
# Data.Niacin                       float64
# Data.Protein                      float64
# Data.Retinol                        int64
# Data.Riboflavin                   float64
# Data.Selenium                     float64
# Data.Sugar Total                  float64
# Data.Thiamin                      float64
# Data.Water                        float64
# Data.Fat.Monosaturated Fat        float64
# Data.Fat.Polysaturated Fat        float64
# Data.Fat.Saturated Fat            float64
# Data.Fat.Total Lipid              float64
# Data.Major Minerals.Calcium         int64
# Data.Major Minerals.Copper        float64
# Data.Major Minerals.Iron          float64
# Data.Major Minerals.Magnesium       int64
# Data.Major Minerals.Phosphorus      int64
# Data.Major Minerals.Potassium       int64
# Data.Major Minerals.Sodium          int64
# Data.Major Minerals.Zinc          float64
# Data.Vitamins.Vitamin A - RAE       int64
# Data.Vitamins.Vitamin B12         float64
# Data.Vitamins.Vitamin B6          float64
# Data.Vitamins.Vitamin C           float64
# Data.Vitamins.Vitamin E           float64
# Data.Vitamins.Vitamin K           float64
# dtype: object

# %%
# Look at the first 2 rows of the dataframe

food_df.head(2)
# Out:
#   Category  Description  Nutrient Data Bank Number  Data.Alpha Carotene  \
# 0     Milk  Milk, human                   11000000                    0
# 1     Milk    Milk, NFS                   11100000                    0
#
#    Data.Beta Carotene  Data.Beta Cryptoxanthin  Data.Carbohydrate  \
# 0                   7                        0               6.89
# 1                   4                        0               4.87
#
#    Data.Cholesterol  Data.Choline  Data.Fiber  ...  \
# 0                14          16.0         0.0  ...
# 1                 8          17.9         0.0  ...
#
#    Data.Major Minerals.Phosphorus  Data.Major Minerals.Potassium  \
# 0                              14                             51
# 1                             103                            157
#
#    Data.Major Minerals.Sodium  Data.Major Minerals.Zinc  \
# 0                          17                      0.17
# 1                          39                      0.42
#
#    Data.Vitamins.Vitamin A - RAE  Data.Vitamins.Vitamin B12  \
# 0                             61                       0.05
# 1                             59                       0.56
#
#    Data.Vitamins.Vitamin B6  Data.Vitamins.Vitamin C  Data.Vitamins.Vitamin E  \
# 0                     0.011                      5.0                     0.08
# 1                     0.060                      0.1                     0.03
#
#    Data.Vitamins.Vitamin K
# 0                      0.3
# 1                      0.2
#
# [2 rows x 38 columns]

# %%
# Look at the last 2 rows of the dataframe

food_df.tail(2)
# Out:
#                                   Category  \
# 7081     Sauce as ingredient in hamburgers
# 7082  Industrial oil as ingredient in food
#
#                                Description  Nutrient Data Bank Number  \
# 7081     Sauce as ingredient in hamburgers                   99998130
# 7082  Industrial oil as ingredient in food                   99998210
#
#       Data.Alpha Carotene  Data.Beta Carotene  Data.Beta Cryptoxanthin  \
# 7081                    0                 194                        4
# 7082                    0                   0                        0
#
#       Data.Carbohydrate  Data.Cholesterol  Data.Choline  Data.Fiber  ...  \
# 7081              17.14                13          20.0         0.6  ...
# 7082               0.00                 0           0.2         0.0  ...
#
#       Data.Major Minerals.Phosphorus  Data.Major Minerals.Potassium  \
# 7081                              33                            190
# 7082                               0                              0
#
#       Data.Major Minerals.Sodium  Data.Major Minerals.Zinc  \
# 7081                         845                      0.21
# 7082                           0                      0.01
#
#       Data.Vitamins.Vitamin A - RAE  Data.Vitamins.Vitamin B12  \
# 7081                             21                       0.04
# 7082                              0                       0.00
#
#       Data.Vitamins.Vitamin B6  Data.Vitamins.Vitamin C  \
# 7081                     0.104                      2.5
# 7082                     0.000                      0.0
#
#       Data.Vitamins.Vitamin E  Data.Vitamins.Vitamin K
# 7081                      1.9                     50.8
# 7082                     10.5                    155.8
#
# [2 rows x 38 columns]

# %%
# Print out summary statistics about the dataframe

food_df.describe()
# Out:
#        Nutrient Data Bank Number  Data.Alpha Carotene  Data.Beta Carotene  \
# count               7.083000e+03          7083.000000         7083.000000
# mean                4.884965e+07            43.759283          255.363405
# std                 2.425159e+07           259.520139          995.709951
# min                 1.100000e+07             0.000000            0.000000
# 25%                 2.715077e+07             0.000000            0.000000
# 50%                 5.326020e+07             0.000000            8.000000
# 75%                 6.720345e+07             1.000000           73.000000
# max                 9.999821e+07          4655.000000        14134.000000
#
#        Data.Beta Cryptoxanthin  Data.Carbohydrate  Data.Cholesterol  \
# count              7083.000000        7083.000000       7083.000000
# mean                  4.862346          20.828039         34.458845
# std                  38.047657          21.887363         77.479105
# min                   0.000000           0.000000          0.000000
# 25%                   0.000000           5.650000          0.000000
# 50%                   0.000000          13.300000          8.000000
# 75%                   1.000000          26.195000         46.000000
# max                1922.000000         100.000000       3074.000000
#
#        Data.Choline   Data.Fiber  Data.Lutein and Zeaxanthin  Data.Lycopene  \
# count   7083.000000  7083.000000                 7083.000000    7083.000000
# mean      34.440802     1.703840                  213.351687     263.571933
# std       43.901497     2.558168                 1015.888615    1161.245139
# min        0.000000     0.000000                    0.000000       0.000000
# 25%       10.000000     0.100000                    0.000000       0.000000
# 50%       19.600000     1.000000                   18.000000       0.000000
# 75%       44.200000     2.100000                   81.000000       0.000000
# max      820.200000    46.200000                15643.000000   45902.000000
#
#        ...  Data.Major Minerals.Phosphorus  Data.Major Minerals.Potassium  \
# count  ...                     7083.000000                    7083.000000
# mean   ...                      133.088945                     217.127488
# std    ...                      126.498700                     204.812523
# min    ...                        0.000000                       0.000000
# 25%    ...                       48.000000                     111.000000
# 50%    ...                      102.000000                     183.000000
# 75%    ...                      189.000000                     270.500000
# max    ...                     1429.000000                    6040.000000
#
#        Data.Major Minerals.Sodium  Data.Major Minerals.Zinc  \
# count                 7083.000000               7083.000000
# mean                   340.503459                  1.281451
# std                    350.333632                  2.917233
# min                      0.000000                  0.000000
# 25%                    124.000000                  0.360000
# 50%                    313.000000                  0.680000
# 75%                    454.000000                  1.360000
# max                   7851.000000                 98.860000
#
#        Data.Vitamins.Vitamin A - RAE  Data.Vitamins.Vitamin B12  \
# count                    7083.000000                7083.000000
# mean                       73.139065                   0.705177
# std                       241.913126                   2.502821
# min                         0.000000                   0.000000
# 25%                         2.000000                   0.000000
# 50%                        20.000000                   0.180000
# 75%                        61.000000                   0.550000
# max                      9363.000000                  82.440000
#
#        Data.Vitamins.Vitamin B6  Data.Vitamins.Vitamin C  \
# count               7083.000000              7083.000000
# mean                   0.197528                 5.696216
# std                    0.374608                15.548490
# min                    0.000000                 0.000000
# 25%                    0.052000                 0.000000
# 50%                    0.110000                 0.700000
# 75%                    0.203000                 5.300000
# max                   12.000000               560.000000
#
#        Data.Vitamins.Vitamin E  Data.Vitamins.Vitamin K
# count              7083.000000              7083.000000
# mean                  1.086955                14.206607
# std                   3.133890                54.944096
# min                   0.000000                 0.000000
# 25%                   0.230000                 0.800000
# 50%                   0.550000                 3.800000
# 75%                   1.110000                 9.300000
# max                 149.400000              1640.000000
#
# [8 rows x 36 columns]

# %%
# Choose a column and print out the column (it's ok if the output is abbreviated)

food_df['Description']
# Out:
# 0                                    Milk, human
# 1                                      Milk, NFS
# 2                                    Milk, whole
# 3                        Milk, low sodium, whole
# 4                 Milk, calcium fortified, whole
#                           ...
# 7078            Tomatoes as ingredient in omelet
# 7079    Other vegetables as ingredient in omelet
# 7080           Vegetables as ingredient in curry
# 7081           Sauce as ingredient in hamburgers
# 7082        Industrial oil as ingredient in food
# Name: Description, Length: 7083, dtype: object

# %%
# Choose a column that has numeric values and make a line plot of the values
import matplotlib.pyplot as plt

set1 = food_df.loc[food_df['Category'] == 'Milk']

# %%
set1.plot(kind='line', y='Data.Carbohydrate')
# Out:
# <AxesSubplot:>

# %%
# Use "loc" to print out the first 10 elements of the plotted column

set1.loc[:9]
# Out:
#   Category                               Description  \
# 0     Milk                               Milk, human
# 1     Milk                                 Milk, NFS
# 2     Milk                               Milk, whole
# 3     Milk                   Milk, low sodium, whole
# 4     Milk            Milk, calcium fortified, whole
# 5     Milk     Milk, calcium fortified, low fat (1%)
# 6     Milk  Milk, calcium fortified, fat free (skim)
# 7     Milk                    Milk, reduced fat (2%)
# 8     Milk           Milk, acidophilus, low fat (1%)
# 9     Milk       Milk, acidophilus, reduced fat (2%)
#
#    Nutrient Data Bank Number  Data.Alpha Carotene  Data.Beta Carotene  \
# 0                   11000000                    0                   7
# 1                   11100000                    0                   4
# 2                   11111000                    0                   7
# 3                   11111100                    0                   7
# 4                   11111150                    0                   7
# 5                   11111160                    0                   1
# 6                   11111170                    0                   0
# 7                   11112110                    0                   3
# 8                   11112120                    0                   1
# 9                   11112130                    0                   3
#
#    Data.Beta Cryptoxanthin  Data.Carbohydrate  Data.Cholesterol  Data.Choline  \
# 0                        0               6.89                14          16.0
# 1                        0               4.87                 8          17.9
# 2                        0               4.67                12          17.8
# 3                        0               4.46                14          16.0
# 4                        0               4.67                12          17.8
# 5                        0               5.19                 5          17.4
# 6                        0               4.85                 2          16.0
# 7                        0               4.91                 8          18.2
# 8                        0               5.19                 5          17.4
# 9                        0               4.91                 8          18.2
#
#    Data.Fiber  ...  Data.Major Minerals.Phosphorus  \
# 0         0.0  ...                              14
# 1         0.0  ...                             103
# 2         0.0  ...                             101
# 3         0.0  ...                              86
# 4         0.0  ...                             101
# 5         0.0  ...                             103
# 6         0.0  ...                             101
# 7         0.0  ...                             103
# 8         0.0  ...                             103
# 9         0.0  ...                             103
#
#    Data.Major Minerals.Potassium  Data.Major Minerals.Sodium  \
# 0                             51                          17
# 1                            157                          39
# 2                            150                          38
# 3                            253                           3
# 4                            150                          38
# 5                            159                          39
# 6                            166                          52
# 7                            159                          39
# 8                            159                          39
# 9                            159                          39
#
#    Data.Major Minerals.Zinc  Data.Vitamins.Vitamin A - RAE  \
# 0                      0.17                             61
# 1                      0.42                             59
# 2                      0.41                             32
# 3                      0.38                             29
# 4                      0.41                             32
# 5                      0.43                             58
# 6                      0.40                            137
# 7                      0.43                             83
# 8                      0.43                             58
# 9                      0.43                             83
#
#    Data.Vitamins.Vitamin B12  Data.Vitamins.Vitamin B6  \
# 0                       0.05                     0.011
# 1                       0.56                     0.060
# 2                       0.54                     0.061
# 3                       0.36                     0.034
# 4                       0.54                     0.061
# 5                       0.61                     0.060
# 6                       0.38                     0.040
# 7                       0.55                     0.061
# 8                       0.61                     0.060
# 9                       0.55                     0.061
#
#    Data.Vitamins.Vitamin C  Data.Vitamins.Vitamin E  Data.Vitamins.Vitamin K
# 0                      5.0                     0.08                      0.3
# 1                      0.1                     0.03                      0.2
# 2                      0.0                     0.05                      0.3
# 3                      0.9                     0.08                      0.3
# 4                      0.0                     0.05                      0.3
# 5                      0.0                     0.02                      0.1
# 6                      1.0                     0.01                      0.0
# 7                      0.2                     0.03                      0.2
# 8                      0.0                     0.02                      0.1
# 9                      0.2                     0.03                      0.2
#
# [10 rows x 38 columns]

# %%
# Use "loc" to print out the first 10 elements of the plotted column
# as well as the matching 10 elements of a different column that has interesting text
food_df.loc[0:9,['Description','Data.Carbohydrate']]
# Out:
#                                 Description  Data.Carbohydrate
# 0                               Milk, human               6.89
# 1                                 Milk, NFS               4.87
# 2                               Milk, whole               4.67
# 3                   Milk, low sodium, whole               4.46
# 4            Milk, calcium fortified, whole               4.67
# 5     Milk, calcium fortified, low fat (1%)               5.19
# 6  Milk, calcium fortified, fat free (skim)               4.85
# 7                    Milk, reduced fat (2%)               4.91
# 8           Milk, acidophilus, low fat (1%)               5.19
# 9       Milk, acidophilus, reduced fat (2%)               4.91

# %%
# Assign the dataframe values from the previous cell into a new dataframe variable
# and make a bar plot with the text values horizontally and the numeric values as the bar heights

new_food_df = food_df.loc[0:9,['Description','Data.Carbohydrate']]

new_food_df.plot(kind='bar',
             x='Description',
             y='Data.Carbohydrate',
             figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Description'>

# %%
# Re-do the plot from the previous cell as a horizontal bar plot

new_food_df.plot(kind='barh',
             x='Description',
             y='Data.Carbohydrate',
             figsize=(12,5))
# Out:
# <AxesSubplot:ylabel='Description'>

# %%
# Re-do the plot from the previous cell
# and change at least two aesthetic elements (colors, labels, titles, ...)

barcolors = []
for i in new_food_df.index:
    if new_food_df['Data.Carbohydrate'][i] > 5:
        barcolors.append('lightseagreen')
    elif new_food_df['Data.Carbohydrate'][i] < 5:
        barcolors.append('turquoise')

ax = new_food_df.plot(kind='barh',
             x='Description',
             y='Data.Carbohydrate',
             figsize=(12,5),
             color=barcolors)
ax.legend(['Carbohydrates'])
ax.set_title('Carbohydrate Amount in Different Milks', fontsize=15)
ax.set_xlabel('Carbohydrates',fontsize=13)
ax.set_ylabel('Milk Type',fontsize=13)
# Out:
# Text(0, 0.5, 'Milk Type')

# %% [markdown]
# # Free form section

# %% [markdown]
# * Choose another type of plot that interests you from the [pandas.DataFrame.plot documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html#) [look at the 'kind' parameter] and make a new plot of your dataset values using the plot type

# %%
new_food_df.plot(kind='density',
             x='Description',
             y='Data.Carbohydrate',
             figsize=(12,5))
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# * Copy some of your analysis from the Week 2 assignment into new cells below
# * Clean them up if desired, and make sure that you translate them to work with your new pandas dataframe structure here if needed
# * Create several plots to complement and extend your analysis

# %%
import food
report = food.get_report()
yogurtDict = report[48]
yogurtNutritionDict = yogurtDict['Data']
yogurtNutritionDict
# Out:
# {'Alpha Carotene': 0,
#  'Beta Carotene': 5,
#  'Beta Cryptoxanthin': 0,
#  'Carbohydrate': 4.66,
#  'Cholesterol': 13,
#  'Choline': 15.2,
#  'Fiber': 0.0,
#  'Lutein and Zeaxanthin': 0,
#  'Lycopene': 0,
#  'Niacin': 0.075,
#  'Protein': 3.47,
#  'Retinol': 27,
#  'Riboflavin': 0.142,
#  'Selenium': 2.2,
#  'Sugar Total': 4.66,
#  'Thiamin': 0.029,
#  'Water': 87.89,
#  'Fat': {'Monosaturated Fat': 0.893,
#   'Polysaturated Fat': 0.092,
#   'Saturated Fat': 2.096,
#   'Total Lipid': 3.25},
#  'Major Minerals': {'Calcium': 121,
#   'Copper': 0.009,
#   'Iron': 0.05,
#   'Magnesium': 12,
#   'Phosphorus': 95,
#   'Potassium': 155,
#   'Sodium': 46,
#   'Zinc': 0.59},
#  'Vitamins': {'Vitamin A - RAE': 27,
#   'Vitamin B12': 0.37,
#   'Vitamin B6': 0.032,
#   'Vitamin C': 0.5,
#   'Vitamin E': 0.06,
#   'Vitamin K': 0.2}}

# %%
#get rid of sub dictionaries

def recursiveflatten(parentDict, subDict):
    for key in list(subDict.keys()):
        if type(subDict[key]) == type(dict()):
            recursiveflatten(parentDict, subDict[key])
            subDict.pop(key)
        else:
            parentDict[key] = subDict[key]

recursiveflatten(yogurtNutritionDict, yogurtNutritionDict)
#yogurtNutritionDict


#make table of keys and values of yogurt nutrition facts

yoNutriList = list(yogurtNutritionDict)
yoNutriList2 = list(yogurtNutritionDict.values())
pd.DataFrame(yoNutriList2, yoNutriList)
# Out:
#                              0
# Alpha Carotene           0.000
# Beta Carotene            5.000
# Beta Cryptoxanthin       0.000
# Carbohydrate             4.660
# Cholesterol             13.000
# Choline                 15.200
# Fiber                    0.000
# Lutein and Zeaxanthin    0.000
# Lycopene                 0.000
# Niacin                   0.075
# Protein                  3.470
# Retinol                 27.000
# Riboflavin               0.142
# Selenium                 2.200
# Sugar Total              4.660
# Thiamin                  0.029
# Water                   87.890
# Monosaturated Fat        0.893
# Polysaturated Fat        0.092
# Saturated Fat            2.096
# Total Lipid              3.250
# Calcium                121.000
# Copper                   0.009
# Iron                     0.050
# Magnesium               12.000
# Phosphorus              95.000
# Potassium              155.000
# Sodium                  46.000
# Zinc                     0.590
# Vitamin A - RAE         27.000
# Vitamin B12              0.370
# Vitamin B6               0.032
# Vitamin C                0.500
# Vitamin E                0.060
# Vitamin K                0.200

# %%
yogurtGraph = pd.DataFrame(yoNutriList2, yoNutriList)

ax = yogurtGraph.plot(kind='bar',
             figsize=(12,5))
ax.legend(['mg'])
ax.set_title('Yogurt Nutrition Facts', fontsize=15)
ax.set_xlabel('Nutrition',fontsize=13)
ax.set_ylabel('mg',fontsize=13)
# Out:
# Text(0, 0.5, 'mg')

# %%
ax = yogurtGraph.plot(kind='barh',
             figsize=(12,5))
ax.legend(['mg'])
ax.set_title('Yogurt Nutrition Facts', fontsize=15)
ax.set_xlabel('mg',fontsize=13)
ax.set_ylabel('Nutrition',fontsize=13)
# Out:
# Text(0, 0.5, 'Nutrition')

# %%
yogurtGraph.plot(kind='pie',
    figsize=(15,15),
    subplots=True)
# Out:
# array([<AxesSubplot:ylabel='0'>], dtype=object)
